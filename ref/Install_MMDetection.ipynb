# %% [markdown]
# # Installing MMDetection framework

# %%
# N.B. This is a bug in the mmcv framework. For more details check out the article below:
# https://github.com/open-mmlab/mmocr/issues/2041

# Solution: install a lower version of mmcv

# %%
# install anaconda

# create a conda environment and activate it

# install from the command line

# !conda create --name openmmlab python=3.8 -y
# !conda activate openmmlab
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Sparrow\MiniConda3\envs\openmmlab
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.9.24  |       haa95532_0         131 KB
#     libffi-3.4.4               |       hd77b12b_1         122 KB
#     openssl-3.0.15             |       h827c3e9_0         7.8 MB
#     pip-24.2                   |   py38haa95532_0         2.4 MB
#     python-3.8.20              |       h8205438_0        19.4 MB
#     setuptools-75.1.0          |   py38haa95532_0         1.6 MB
#     sqlite-3.45.3              |       h2bbff1b_0         973 KB
#     vc-14.40                   |       h2eaa2aa_1          10 KB
#     vs2015_runtime-14.40.33807 |       h98bb1dd_1         1.3 MB
# ...

# %%
# !conda install pytorch torchvision cpuonly -c pytorch # for CPU

# !conda install pytorch torchvision -c pytorch # for GPU systems
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'pytorch'

# %%
# Install MMEngine and MMCV using MIM

# !pip install -U openmim
# !mim install mmengine

# mim install "mmcv>=2.0.0"
# this is the official command. It will install the latest version. this creates problems. I
# instead use the following. This works.

# !mim install "mmcv==2.1.0"

# %%
# install mmdet

# !mim install mmdet

# %% [markdown]
# # Verify the installation.

# %%
# download config and checkpoint files.

# !mim download mmdet --config rtmdet_tiny_8xb32-300e_coco --dest

# %%
# !ls
# Out:
# sample_data

# %%
# create a new directory (demo) in your working directory and copy the following file inside it
# https://github.com/open-mmlab/mmdetection/blob/main/demo/demo.jpg.
# you will run inference on this

# %%
# run the following Python code

from mmdet.apis import init_detector, inference_detector

config_file = 'rtmdet_tiny_8xb32-300e_coco.py'
checkpoint_file = 'rtmdet_tiny_8xb32-300e_coco_20220902_112414-78e30dcc.pth'

model = init_detector(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'

inference_detector(model, 'demo/demo.jpg')

# You will see a list of DetDataSample, and the predictions are in the pred_instance, indicating the detected bounding boxes, labels, and scores.
